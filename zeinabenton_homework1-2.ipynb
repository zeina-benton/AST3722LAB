# %%
# %pip install --pre astroquery
# %pip install astroplan
# %pip install scikit-image
# %pip install photutils
# %pip install ipywidgets
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 2.8 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for astroplan: filename=astroplan-0.10.1-py3-none-any.whl size=83856 sha256=7c71983f9666919eddb73e1cc589cd7d0adb9dadcc21461d7e58d8ef0eb225fe
#   Stored in directory: /Users/zeinakellybenton/Library/Caches/pip/wheels/e1/7c/33/94b51d82014aa0e505e9f7c1f62168ea430ada61b9327052c2
# Successfully built astroplan
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 6.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 21.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
#1
def Add(number,number2):
    print(number + number2)
    
Add(1,2)
# Out:
# 3

# %%
#2
def exponent(number,number2):
    print(number**number2)

exponent(3,5)
# Out:
# 243

# %%
#3
import numpy

cube= numpy.array([1,2,3,4])
result=numpy.power(cube,3)

print(result)
# Out:
# [ 1  8 27 64]

# %%
#4
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([0,1])

# %%
#5

plt.plot(cube, result)
plt.xlabel('Values 1,2,3,4')
plt.ylabel('Values Cubed')
plt.title('Values Normal Vs Cubed')

plt.show()

# %% [markdown]
# #6
# # Markdown Cell
# __This text is bold__
# _This text is italicized_

# %%
#7
import astropy, astroplan, skimage, photutils, astroquery
print(astropy.__version__, astroplan.__version__, astroquery.__version__)
# Out:
# 6.1.7 0.10.1 0.4.6

# %%
#Resources
#https://www.geeksforgeeks.org/sum-function-python/ for 1
#https://matplotlib.org/stable/api/pyplot_summary.html for 5
